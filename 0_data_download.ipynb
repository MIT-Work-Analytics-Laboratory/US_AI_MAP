# %%
import pandas as pd
import wrds
import os
from tqdm import tqdm
from datetime import datetime

# %%
# Connect to WRDS database
print("Connecting to WRDS database...")
db = wrds.Connection(wrds_username="pibou149", verbose=True)
print("✓ Successfully connected to WRDS!")

# Define paths
notebook_dir = os.path.dirname(os.path.abspath("__file__"))
output_path = "/Volumes/LaCie/revelio_microdata"

print(f"\nNotebook directory: {notebook_dir}")
print(f"Output path: {output_path}")
# Out:
# Connecting to WRDS database...
# postgresql://pibou149:@wrds-pgdata.wharton.upenn.edu:9737/wrds
# Loading library list...
# Done
# ✓ Successfully connected to WRDS!
#
# Notebook directory: /Users/pibou/Documents/GitHub/plek_ai_research/wal_map
# Output path: /Volumes/LaCie/revelio_microdata

# %% [markdown]
# # Download all U.S employee Revelio IDs

# %%
EMPLOYEE_LIST_QUERY = ("""
    SELECT
        revelio_individual.individual_user.user_id,
        revelio_individual.individual_user.user_country
    
    FROM revelio_individual.individual_user
    
    WHERE 1 = 1
    
    AND ("revelio_individual"."individual_user"."user_country" = 'United States')
""")
#This takes forever, run it through the Wharton cluster.
#employee_df = db.raw_sql(EMPLOYEE_LIST_QUERY)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 13
#       1 EMPLOYEE_LIST_QUERY = ("""
#       2     SELECT
#       3         revelio_individual.individual_user.user_id,
#    (...)
#      10     AND ("revelio_individual"."individual_user"."user_country" = 'United States')
#      11 """)
# ---> 13 employee_df = db.raw_sql(EMPLOYEE_LIST_QUERY)
#
# File ~/anaconda3/envs/DataAnalysis/lib/python3.11/site-packages/wrds/sql.py:591, in Connection.raw_sql(self, sql, coerce_float, date_cols, index_col, params, chunksize, return_iter, dtype, dtype_backend)
#     589         full_df = pd.DataFrame()
#     590         for chunk in df:
# --> 591             full_df = pd.concat([full_df, chunk])
#     592         return full_df
#     593 except sa.exc.ProgrammingError as e:
#
# ...
